# %%
import numpy as np
from sklearn.neural_network import MLPClassifier
from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

# %%
# Datos
x, y = fetch_openml( 'mnist_784' , version=1, return_X_y=True)
x = x / 255.0 # Escalan los valores de rango [O, 1]
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
model = MLPClassifier(hidden_layer_sizes=(100,),activation='relu',solver='adam',random_state=42) 

model.fit(X_train, y_train)
# Evalua
y_pred = model.predict (X_test)
accuracy = accuracy_score (y_test, y_pred)
print(f'precision del modelo en el conjunto de prueba: {accuracy*100} %')
# Out:
# precision del modelo en el conjunto de prueba: 97.55 %

# %%
perdida=model.loss_curve_
precision=model.validation_scores_

fig, axs = plt.subplots( layout='constrained',figsize=(9, 2.7))
axs.plot(perdida)
axs.set_title('Squared Error X N# iterations ')
# Out:
# Text(0.5, 1.0, 'Squared Error X N# iterations ')
